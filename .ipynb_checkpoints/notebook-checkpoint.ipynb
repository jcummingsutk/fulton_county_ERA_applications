# %% [markdown]
# # A Predictive Tool for those Who Need Rental Assistance in Fulton County, GA
#
# Some useful links:
#
# * [program details](https://www.fultoncountyga.gov/covid-19/rental-assistance)
#
# * [additional program info](https://sharefulton.fultoncountyga.gov/stories/s/Emergency-Rental/22ag-mzc6)
#
# * [dataset](https://sharefulton.fultoncountyga.gov/Health-Human-Services/Neighborly-ERA-Applications/std8-6vc9)
#
#
# The Emergency Rent and Utility Assistance (ERA) program is a program throughout the united states that assists families that are in need of emergency assistance for rent and utilities resulting from the COVID-19 pandemic. Residents have to meet eligibility requirements by the federal government, including
#
# * One or more individuals within the household has qualified for unemployment benefits or experienced a reduction in household income, incurred significant costs, or experienced other financial hardship due, directly or indirectly, to the COVID-19 outbreak;
# * One or more individuals within the household can demonstrate a risk of experiencing homelessness or housing instability; and
# * The household’s income is at or below 80% of the area median income.
#
# Also, an initial exploration of the data shows that when the payment program pays out, it takes on average 100 days for the person to get the money. This is a long time to wait for someone who is struggling due to the pandemic!
#
#
# With the above details in mind, this project aims to answer two questions:
# * Will I receive assistance from the ERA program? Model will be optimized on precision, since if we tell someone that they are going to receive assistance, we want to be reasonable confident in this assrtion.
# * If so, how much assistance will I receive, and when can I expect this assistance?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import (precision_recall_curve, PrecisionRecallDisplay)

# %%
df = pd.read_csv('data/Neighborly_ERA_Applications.csv')
# Out:
# /home/jcummings/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (34,41,42,44,45,46,47) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Utility Functions I Use Often, Parameters Needed

# %%
def calculate_percent_missing(in_df):
    # function which returns a dataframe indicating what percent of a column is missing
    percent_missing = in_df.isnull().sum() * 100 / len(in_df)
    return pd.DataFrame({'percent_missing': percent_missing})
def summary_of_model(clf, X_train, X_test, y_train, y_test):
    from sklearn.model_selection import GridSearchCV
    from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score
    from sklearn.metrics import classification_report
    from sklearn.metrics import accuracy_score, precision_score, recall_score
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import (precision_recall_curve, PrecisionRecallDisplay)
    # This provides a summary of the model, but without the threshold condition.
    # It includes a summary on recall/accuracy on the training and test sets, a visual display of the confusion matrix
    # and a plot of the precision-recall curve for a given classifier.
    pred_test = clf.predict(X_test)
    pred_train = clf.predict(X_train)
    print(classification_report(y_test, pred_test))
    print('Recall on the training set: {:.2f}'.format(recall_score(y_train, pred_train)))
    print('Accuracy on the training set: {:.2f}'.format(accuracy_score(y_train, pred_train)))
    print('Recall on the test set: {:.2f}'.format(recall_score(y_test, pred_test)))
    print('Accuracy on the test set: {:.2f}'.format(accuracy_score(y_test, pred_test)))
    print(confusion_matrix(y_test, pred_test))
    _, ax = plt.subplots(figsize=(9,9))
    ax = sns.heatmap(confusion_matrix(y_test, pred_test), annot=True, fmt='d', cmap='vlag', annot_kws={"size": 40, "weight": "bold"})  
    labels = ['False', 'True']
    ax.set_xticklabels(labels, fontsize=25);
    ax.set_yticklabels(labels, fontsize=25);
    ax.set_ylabel('Actual', fontsize=30);
    ax.set_xlabel('Prediction', fontsize=30)
    lr_probs = clf.predict_proba(X_test)
    lr_probs = lr_probs[:, 1]
    lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs)
    plt.figure()
    plt.plot(lr_recall, lr_precision, marker='.')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.show()

# %%
TEST_FRACTION = .25 #percentage of the test size
CV = 7 #cross validations to do in grid search
OPT_ON = 'f1' #what to optimize in gridsearches
N_JOBS = 7 #number of cores
RAND_STATE = 0 #will be doing multiple train-test-splits, and want to keep everything random, but do the same train-test-splits

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# These data are poorly documented. The goal of this section is to get a rough idea about what the columns represent, how they're represented (types), how much is missing, and remove columns which are obviously not useful.

# %%
# I like that all the columns are lower case. Taking a look at columns and types
df.columns = df.columns.str.lower()
df.columns = df.columns.str.strip()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34963 entries, 0 to 34962
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   row id                                    34963 non-null  int64
#  1   case id                                   34963 non-null  int64
#  2   case status                               34963 non-null  object
#  3   case: date created                        34963 non-null  object
#  4   case: program year                        34963 non-null  int64
#  5   funding total amount                      34963 non-null  float64
#  6   borrower 1: age                           22823 non-null  float64
#  7   borrower 1: ethnicity                     20273 non-null  object
#  8   borrower 1: gender                        21342 non-null  object
#  9   borrower 1: race                          21072 non-null  object
#  10  borrower_1_relationshiptoheadofhousehold  19434 non-null  object
#  11  case: landlord case id                    10468 non-null  float64
#  12  case: landlord case name                  10468 non-null  object
#  13  household ami ratio                       20811 non-null  float64
#  14  household ami ratio rounded               20468 non-null  float64
#  15  household annual income                   22719 non-null  float64
#  16  household monthly income                  22719 non-null  float64
#  17  household size                            22734 non-null  float64
#  18  tenant code                               34963 non-null  object
#  19  submit completed date                     17429 non-null  object
#  20  total rental assistance requested         34963 non-null  float64
#  21  electricity assistance requested          34963 non-null  float64
#  22  gas assistance requested                  34963 non-null  float64
#  23  water assistance requested                34963 non-null  float64
#  24  total utility assistance requested        34963 non-null  float64
#  25  total assistance approved                 34963 non-null  float64
#  26  total assistance requested                34963 non-null  float64
#  27  today                                     34963 non-null  object
#  28  applicantinfo_applicanthome_zip_clean     27478 non-null  float64
#  29  score                                     22442 non-null  float64
#  30  x                                         21474 non-null  float64
#  31  y                                         21474 non-null  float64
#  32  city                                      34963 non-null  object
#  33  district                                  34963 non-null  object
#  34  geocoded                                  25792 non-null  object
#  35  zip_latitude                              27128 non-null  float64
#  36  zip_longitude                             27128 non-null  float64
#  37  cl_latitude                               20589 non-null  float64
#  38  cl_longitude                              20589 non-null  float64
#  39  cd_latitude                               20590 non-null  float64
#  40  cd_longitude                              20590 non-null  float64
#  41  city of atlanta                           20589 non-null  object
#  42  applicant home point                      21474 non-null  object
#  43  percent of request approved               17915 non-null  float64
#  44  city of atlanta (text)                    20589 non-null  object
#  45  out of county                             21472 non-null  object
#  46  out of county text                        21472 non-null  object
#  47  fulton service area                       21472 non-null  object
#  48  fulton service area text                  34963 non-null  object
#  49  check disbursement date                   6107 non-null   object
#  50  ams amount                                6107 non-null   float64
#  51  days from creation to submitted           17429 non-null  float64
#  52  submit to disbursement                    6105 non-null   float64
#  53  duplicate                                 34963 non-null  bool
#  54  case status 2                             34963 non-null  object
# dtypes: bool(1), float64(29), int64(3), object(22)
# memory usage: 14.4+ MB

# %%
# Below we see a lot of missing values.
calculate_percent_missing(df)
# Out:
#                                           percent_missing
# row id                                           0.000000
# case id                                          0.000000
# case status                                      0.000000
# case: date created                               0.000000
# case: program year                               0.000000
# funding total amount                             0.000000
# borrower 1: age                                 34.722421
# borrower 1: ethnicity                           42.015845
# borrower 1: gender                              38.958327
# borrower 1: race                                39.730572
# borrower_1_relationshiptoheadofhousehold        44.415525
# case: landlord case id                          70.059777
# case: landlord case name                        70.059777
# household ami ratio                             40.477076
# household ami ratio rounded                     41.458113
# household annual income                         35.019878
# household monthly income                        35.019878
# household size                                  34.976976
# tenant code                                      0.000000
# submit completed date                           50.150159
# total rental assistance requested                0.000000
# electricity assistance requested                 0.000000
# gas assistance requested                         0.000000
# water assistance requested                       0.000000
# total utility assistance requested               0.000000
# total assistance approved                        0.000000
# total assistance requested                       0.000000
# today                                            0.000000
# applicantinfo_applicanthome_zip_clean           21.408346
# score                                           35.812144
# x                                               38.580785
# y                                               38.580785
# city                                             0.000000
# district                                         0.000000
# geocoded                                        26.230587
# zip_latitude                                    22.409404
# zip_longitude                                   22.409404
# cl_latitude                                     41.112033
# cl_longitude                                    41.112033
# cd_latitude                                     41.109173
# cd_longitude                                    41.109173
# city of atlanta                                 41.112033
# applicant home point                            38.580785
# percent of request approved                     48.760118
# city of atlanta (text)                          41.112033
# out of county                                   38.586506
# out of county text                              38.586506
# fulton service area                             38.586506
# fulton service area text                         0.000000
# check disbursement date                         82.532963
# ams amount                                      82.532963
# days from creation to submitted                 50.150159
# submit to disbursement                          82.538684
# duplicate                                        0.000000
# case status 2                                    0.000000

# %%
# Filtering out columns that are clearly not useful
prelim_useful_cols = ['case status', 'case: date created', 'funding total amount', 'borrower 1: age', 'borrower 1: ethnicity', 'borrower 1: gender', 
                      'borrower 1: race', 'borrower_1_relationshiptoheadofhousehold', 'case: landlord case id', 'household annual income',
                      'household ami ratio', 'household ami ratio rounded', 'household size', 'tenant code', 'total assistance requested', 
                      'total assistance approved', 'score', 'x', 'y', 'applicant home point', 'zip_latitude', 'zip_longitude',
                      'city of atlanta', 'out of county', 'fulton service area', 'ams amount', 'days from creation to submitted', 
                      'submit to disbursement', 'duplicate', 'case status 2']
# Columns not included, and reasoning if relevant:
# Row id, case id, 
# case: program year (redundant with case date)
# household monthly income (have annual income)
# tenant code (there is only one unique value)
# submit completed date (redundant with date created + days from creation to submitted)
# every requested/awarded except the total
# cl/cd lat/long (not documented, don't know what they are)
# applicant home point (redundant with x, y)
# out of county text, fulton service area text (redundant with out of county, fulton service area
# check disbursement date (redundant with days from creation to submitted and submitted to disbursement added to days to creation)
df_prelim = df[prelim_useful_cols]

# %% [markdown]
# Notes, comments on preliminary explore. See some code snippets below for some justifications.
#
# * Date created is a string.
#     * TODO: Change to Datetime
# * I'm guessing that the 'case: landlord case id' is not null only when the landlord requests the money. It is stated in the documentation landlords can request money, but the data are poorly documented and it doesn't specify if this column is not null only if a landlord has requested money.
#     * TODO: Try to find out why landlord cases are null.
# * The applicant zip code has slightly fewer missing values that the zip lat, zip long, so I'll use those
# * Score reflects how 'confident' they are in the geocoding for the lat/long. The 25% quantile is 95 out of 100, so I think I'll drop this column
# * x, y is the borrower's lat-long, and there are more missing of those than of the zip_lat, zip_long. Perhaps when imputing I can use the x,y coordinates, and if not available use the zip_lat, zip_long coordinates, and then impute the rest in some way (mean, median, etc)
#     * TODO: How to impute the missing x, y
# * I'm not sure what cl/cd lat/long are and there are no notes in the data about this. Will drop from analysis.
# * Applicant home point is just a re-implementation of x, y
# * city of atlanta has null, true, and false as a string, nulls probably due to the applicant home point being missing.
#     * TODO: How to impute these values
# * out of county and out of county text appear to be duplicates. Based on the name fulton service area seems to be answering the question 'does fulton service this area' based on its (mainly) inverse relationship with out of county. I'm going to keep 'out of county'.
# * ams amount is amount disbursed. 82.5 percent of the values are missing, which could be due to their request not being approved. Counterintuitively, this differs from the total assistance approved for, though statistically they're quite close. I'll not be using ams amount column, and use the total assistance approved.
# * days from creation to submitted: days from application created to applications submitted
# * submit to disbursement: days from application submitted to disbursement of check (if approved)
# * duplicate data column:
#     * TODO: delete duplicates
# * Why is there a case status 2. It looks to be a repeat of case status.
#     * TODO: confirm that case status 2 is a repeat of case status.

# %%
# I am not sure why there is a column for both amount of money approved, and the amount of money disbursed. 

# I'll only want to take a look at the cases which are paid or denied. 
denied_paid_mask = (df_prelim['case status']=='Denied') | (df_prelim['case status']=='Paid')
df_appcomp = df_prelim[denied_paid_mask]

# The amount approved and the ams amount differ in their values, which is unexpected. Statistically they're relatively close.
df_appcomp[df_appcomp['ams amount']>0].loc[:, ['total assistance approved', 'ams amount']].describe()
# Out:
#        total assistance approved    ams amount
# count                4370.000000   4370.000000
# mean                 6596.151993   7072.066792
# std                  4618.877793   4971.201766
# min                     0.000000     37.590000
# 25%                  3984.980000   4145.762500
# 50%                  5643.615000   5935.830000
# 75%                  7800.000000   8018.502500
# max                 63000.000000  63000.000000

# %%
# Clearly a lot of tha values are the same. But a lot different as well.
# This is very interesting, and could be investigated further. However, without good documentation, I'm going to move forward with 
# assuming that the amount approved for is how much total money the applicant will receive

# Interesting to note is that there are two "lines" in the data. one is the identity, which one would expect what this graph should be
# A hand calculation reveals that the other line has slope .5, which could mean that the ams amount indicates that the applicant
# received two checks totaling the amount of money that they were approved for

#The above does not explain ams amounts that are more than the total assistance approved. I will continue to assume that the amount of 
# assistance approved is how much they will receive, but more information on the data would be useful here.
sns.set_style('whitegrid', {'grid.linestyle':'--'})
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.scatterplot(data = df_appcomp, x = 'ams amount', y = 'total assistance approved', hue = 'case status')
# Out:
# <AxesSubplot:xlabel='ams amount', ylabel='total assistance approved'>

# %%
sns.scatterplot(data = df_appcomp, x = 'funding total amount', y = 'total assistance approved', hue = 'case status')
# Out:
# <AxesSubplot:xlabel='funding total amount', ylabel='total assistance approved'>

# %%
# Going to drop funding total amount and ams amount due to the previous two cells' discussion
df_appcomp.drop(['funding total amount', 'ams amount'], axis=1, inplace=True)
df_appcomp.describe()
# Out:
# /home/jcummings/.local/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#        borrower 1: age  case: landlord case id  household annual income  \
# count     15031.000000             7080.000000             15044.000000
# mean         35.543876            44951.480650             20032.629020
# std          13.778001             7865.651474             21874.861226
# min         -77.000000            30018.000000                 0.000000
# 25%          28.000000            41208.000000                 0.000000
# 50%          34.000000            45884.500000             13951.000000
# 75%          43.000000            48368.000000             35504.757500
# max         122.000000            75659.000000            445940.000000
#
#        household ami ratio  household ami ratio rounded  household size  \
# count         14360.000000                 14107.000000    15055.000000
# mean             31.069111                    45.592968        1.926137
# std              31.818416                    20.363761        1.301650
# min             -94.650000                    30.000000        1.000000
# 25%               0.000000                    30.000000        1.000000
# 50%              23.010000                    30.000000        1.000000
# 75%              56.267500                    60.000000        3.000000
# max             517.410000                    80.000000       11.000000
#
#        total assistance requested  total assistance approved         score  \
# count                1.716700e+04               17167.000000  14355.000000
# mean                 6.614805e+03                1749.738142     94.845448
# std                  1.684185e+04                3766.063807     18.216057
# min                 -1.154000e+03                   0.000000      0.000000
# 25%                  1.994050e+02                   0.000000     98.325000
# 50%                  3.900000e+03                   0.000000    100.000000
# 75%                  8.070000e+03                1855.125000    100.000000
# max                  1.275116e+06               63000.000000    100.000000
#
#                   x             y  zip_latitude  zip_longitude  \
# count  13865.000000  13865.000000  16606.000000   16606.000000
# mean     -84.399539     33.718698     33.740461     -84.442037
# std        1.929677      0.780679      0.133708       0.101492
# min     -119.255492      0.000000     33.212721     -85.012164
# 25%      -84.495651     33.643532     33.641684     -84.528002
# 50%      -84.449101     33.708076     33.707026     -84.447896
# 75%      -84.379041     33.783028     33.792701     -84.382684
# max        0.000000     41.557467     34.253365     -83.676030
#
#        days from creation to submitted  submit to disbursement
# count                     13065.000000             4370.000000
# mean                          9.150861               73.164302
# std                          29.994868               52.970165
# min                           0.000000              -16.000000
# 25%                           0.000000               34.000000
# 50%                           0.000000               54.000000
# 75%                           3.000000              109.000000
# max                         300.000000              293.000000

# %%
#score's (measuring how accurate their geolocation is) median is 100%, so we'll drop it and assume 100% accuracy.
df_appcomp['score'].describe()
# Out:
# count    14355.000000
# mean        94.845448
# std         18.216057
# min          0.000000
# 25%         98.325000
# 50%        100.000000
# 75%        100.000000
# max        100.000000
# Name: score, dtype: float64

# %%
df_appcomp.drop('score', axis=1, inplace=True)
# Out:
# /home/jcummings/.local/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# checking to see if the applicant home point is just repeating the x and y lat-long coordinates
# looks to be that this is the case.
df_appcomp.loc[:, ['x','y','applicant home point']]
# Out:
#                x          y              applicant home point
# 3     -84.264106  33.696984   POINT (33.69698372 -84.2641062)
# 4     -84.525137  33.589582  POINT (33.58958238 -84.52513744)
# 6     -84.371456  33.821431  POINT (33.82143067 -84.37145649)
# 8     -84.535033  33.585610  POINT (33.58561015 -84.53503346)
# 10    -84.420330  33.598609  POINT (33.59860901 -84.42032996)
# ...          ...        ...                               ...
# 34954        NaN        NaN                               NaN
# 34956        NaN        NaN                               NaN
# 34958        NaN        NaN                               NaN
# 34959        NaN        NaN                               NaN
# 34962        NaN        NaN                               NaN
#
# [17167 rows x 3 columns]

# %%
df_appcomp.drop('applicant home point', axis=1, inplace=True)
# Out:
# /home/jcummings/.local/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# Taking a look at a summary of only cases which were paid or resolved, since there are a lot of applications under review and I'll probably only
# want to consider resolved cases in my analysis.

# Notes: 
# Minimum borrower age is negative, as well as minimum ami ratio (though the rounded one is not). Should take a look at the relationship.
# The median of assistance approved is 0 dollars indicating most applicants do not receive money. I'd like to take a look at this as well.

# %%
df_appcomp.describe()
# Out:
#        borrower 1: age  case: landlord case id  household annual income  \
# count     15031.000000             7080.000000             15044.000000
# mean         35.543876            44951.480650             20032.629020
# std          13.778001             7865.651474             21874.861226
# min         -77.000000            30018.000000                 0.000000
# 25%          28.000000            41208.000000                 0.000000
# 50%          34.000000            45884.500000             13951.000000
# 75%          43.000000            48368.000000             35504.757500
# max         122.000000            75659.000000            445940.000000
#
#        household ami ratio  household ami ratio rounded  household size  \
# count         14360.000000                 14107.000000    15055.000000
# mean             31.069111                    45.592968        1.926137
# std              31.818416                    20.363761        1.301650
# min             -94.650000                    30.000000        1.000000
# 25%               0.000000                    30.000000        1.000000
# 50%              23.010000                    30.000000        1.000000
# 75%              56.267500                    60.000000        3.000000
# max             517.410000                    80.000000       11.000000
#
#        total assistance requested  total assistance approved             x  \
# count                1.716700e+04               17167.000000  13865.000000
# mean                 6.614805e+03                1749.738142    -84.399539
# std                  1.684185e+04                3766.063807      1.929677
# min                 -1.154000e+03                   0.000000   -119.255492
# 25%                  1.994050e+02                   0.000000    -84.495651
# 50%                  3.900000e+03                   0.000000    -84.449101
# 75%                  8.070000e+03                1855.125000    -84.379041
# max                  1.275116e+06               63000.000000      0.000000
#
#                   y  zip_latitude  zip_longitude  \
# count  13865.000000  16606.000000   16606.000000
# mean      33.718698     33.740461     -84.442037
# std        0.780679      0.133708       0.101492
# min        0.000000     33.212721     -85.012164
# 25%       33.643532     33.641684     -84.528002
# 50%       33.708076     33.707026     -84.447896
# 75%       33.783028     33.792701     -84.382684
# max       41.557467     34.253365     -83.676030
#
#        days from creation to submitted  submit to disbursement
# count                     13065.000000             4370.000000
# mean                          9.150861               73.164302
# std                          29.994868               52.970165
# min                           0.000000              -16.000000
# 25%                           0.000000               34.000000
# 50%                           0.000000               54.000000
# 75%                           3.000000              109.000000
# max                         300.000000              293.000000

# %%
# Looks like they're rounding to the 30, 50, 60, and 80 percentile for ami ratio
sns.scatterplot(data = df_appcomp, x = 'household ami ratio', y = 'household ami ratio rounded', hue = 'case status')
# Out:
# <AxesSubplot:xlabel='household ami ratio', ylabel='household ami ratio rounded'>

# %%
# One would expect to see a relationship between household ami ratio and approval assistance, but there doesn't appear to be one
sns.scatterplot(data = df_appcomp, x = 'household ami ratio', y = 'total assistance approved', hue = 'case status')
# Out:
# <AxesSubplot:xlabel='household ami ratio', ylabel='total assistance approved'>

# %%
sns.regplot(data = df_appcomp, x = 'household ami ratio', y = 'total assistance approved')
# Out:
# <AxesSubplot:xlabel='household ami ratio', ylabel='total assistance approved'>

# %%
df_appcomp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17167 entries, 3 to 34962
# Data columns (total 26 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   case status                               17167 non-null  object
#  1   case: date created                        17167 non-null  object
#  2   borrower 1: age                           15031 non-null  float64
#  3   borrower 1: ethnicity                     13370 non-null  object
#  4   borrower 1: gender                        14063 non-null  object
#  5   borrower 1: race                          13900 non-null  object
#  6   borrower_1_relationshiptoheadofhousehold  12820 non-null  object
#  7   case: landlord case id                    7080 non-null   float64
#  8   household annual income                   15044 non-null  float64
#  9   household ami ratio                       14360 non-null  float64
#  10  household ami ratio rounded               14107 non-null  float64
#  11  household size                            15055 non-null  float64
#  12  tenant code                               17167 non-null  object
#  13  total assistance requested                17167 non-null  float64
#  14  total assistance approved                 17167 non-null  float64
#  15  x                                         13865 non-null  float64
#  16  y                                         13865 non-null  float64
#  17  zip_latitude                              16606 non-null  float64
#  18  zip_longitude                             16606 non-null  float64
#  19  city of atlanta                           13014 non-null  object
#  20  out of county                             13865 non-null  object
#  21  fulton service area                       13865 non-null  object
#  22  days from creation to submitted           13065 non-null  float64
#  23  submit to disbursement                    4370 non-null   float64
#  24  duplicate                                 17167 non-null  bool
#  25  case status 2                             17167 non-null  object
# dtypes: bool(1), float64(14), object(11)
# memory usage: 3.4+ MB

# %%
# It will be helpful to have the case status as 0 for denied, 1 for paid. Then mean of that column is a percentage.
approved_mask = ((df_appcomp['total assistance approved']>=df_appcomp['total assistance requested']) & (df_appcomp['total assistance requested'] > 300))
denied_mask = (df_appcomp['case status']=='Denied')
df_appcomp.loc[:, 'case status numeric'] = 0.0
df_appcomp.loc[approved_mask,  'case status numeric'] = 1.0
# Out:
# /home/jcummings/.local/lib/python3.6/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/jcummings/.local/lib/python3.6/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df_appcomp[['case status numeric', 'total assistance approved', 'total assistance requested', 'case status']]
# Out:
#        case status numeric  total assistance approved  \
# 3                      0.0                       0.00
# 4                      0.0                       0.00
# 6                      0.0                       0.00
# 8                      0.0                       0.00
# 10                     0.0                       0.00
# ...                    ...                        ...
# 34954                  0.0                       0.00
# 34956                  1.0                    7659.01
# 34958                  1.0                    6132.89
# 34959                  1.0                    2656.99
# 34962                  0.0                    5268.50
#
#        total assistance requested case status
# 3                         5254.38      Denied
# 4                         5320.00      Denied
# 6                        17991.89      Denied
# 8                        10408.00      Denied
# 10                        3749.00      Denied
# ...                           ...         ...
# 34954                    38210.00      Denied
# 34956                     5131.01        Paid
# 34958                     2881.28        Paid
# 34959                     1916.00        Paid
# 34962                    15804.00        Paid
#
# [17167 rows x 4 columns]

# %%
# I'd like to see what percent of people are approved based on their rounded ami ratio, though I am a bit confused as to how they are rounding

# This is strange. I expected those households with a lower ami to have a higher percentage of people getting
def averager(x):
    names = {
        'case status numeric mean': x['case status numeric'].mean()
    }
    return pd.Series(names, index=['case status numeric mean'])

df_appcomp.groupby('household ami ratio rounded').apply(averager)
# Out:
#                              case status numeric mean
# household ami ratio rounded
# 30.0                                         0.103733
# 50.0                                         0.193882
# 60.0                                         0.239875
# 80.0                                         0.272960

# %%
# I thought perhaps grouping by household size would help too, but still is quite odd, though
# makes more sense in the sense that the numeric mean tends to increase with household size.
df_appcomp.groupby(['household ami ratio rounded','household size']).apply(averager)
# Out:
#                                             case status numeric mean
# household ami ratio rounded household size
# 30.0                        1.0                             0.078676
#                             2.0                             0.124823
#                             3.0                             0.141063
#                             4.0                             0.141046
#                             5.0                             0.149007
#                             6.0                             0.161017
#                             7.0                             0.162162
#                             8.0                             0.083333
#                             9.0                             0.166667
#                             10.0                            0.000000
#                             11.0                            0.000000
# 50.0                        1.0                             0.151628
#                             2.0                             0.194915
#                             3.0                             0.267380
#                             4.0                             0.263158
#                             5.0                             0.162162
#                             6.0                             0.379310
#                             7.0                             0.400000
#                             8.0                             0.250000
# 60.0                        1.0                             0.210826
#                             2.0                             0.291667
#                             3.0                             0.315789
#                             4.0                             0.234043
#                             5.0                             0.187500
#                             6.0                             0.000000
#                             7.0                             0.000000
# 80.0                        1.0                             0.208382
#                             2.0                             0.369301
#                             3.0                             0.339523
#                             4.0                             0.347222
#                             5.0                             0.222222
#                             6.0                             0.411765
#                             7.0                             0.500000
#                             8.0                             1.000000
#                             9.0                             0.000000

# %%
# Taking a look at the percent missing data in each column
calculate_percent_missing(df_appcomp)
# Out:
#                                           percent_missing
# case status                                      0.000000
# case: date created                               0.000000
# borrower 1: age                                 12.442477
# borrower 1: ethnicity                           22.118017
# borrower 1: gender                              18.081202
# borrower 1: race                                19.030698
# borrower_1_relationshiptoheadofhousehold        25.321838
# case: landlord case id                          58.758082
# household annual income                         12.366750
# household ami ratio                             16.351139
# household ami ratio rounded                     17.824897
# household size                                  12.302674
# tenant code                                      0.000000
# total assistance requested                       0.000000
# total assistance approved                        0.000000
# x                                               19.234578
# y                                               19.234578
# zip_latitude                                     3.267898
# zip_longitude                                    3.267898
# city of atlanta                                 24.191763
# out of county                                   19.234578
# fulton service area                             19.234578
# days from creation to submitted                 23.894682
# submit to disbursement                          74.544184
# duplicate                                        0.000000
# case status 2                                    0.000000
# case status numeric                              0.000000

# %%
# Perhaps out of county is the inverse of fulton service area. It looks that way
df_appcomp[['out of county', 'fulton service area']]
# Out:
#       out of county fulton service area
# 3              True               False
# 4             False                True
# 6             False               False
# 8             False                True
# 10             True               False
# ...             ...                 ...
# 34954           NaN                 NaN
# 34956           NaN                 NaN
# 34958           NaN                 NaN
# 34959           NaN                 NaN
# 34962           NaN                 NaN
#
# [17167 rows x 2 columns]

# %%
# Let's see exactly how many are 'out of county' and also 'in fulton service area'. Looks like there are none.
df_appcomp[(df_appcomp['fulton service area']==True) & (df_appcomp['out of county']==True)]
# Out:
# Empty DataFrame
# Columns: [case status, case: date created, borrower 1: age, borrower 1: ethnicity, borrower 1: gender, borrower 1: race, borrower_1_relationshiptoheadofhousehold, case: landlord case id, household annual income, household ami ratio, household ami ratio rounded, household size, tenant code, total assistance requested, total assistance approved, x, y, zip_latitude, zip_longitude, city of atlanta, out of county, fulton service area, days from creation to submitted, submit to disbursement, duplicate, case status 2, case status numeric]
# Index: []
#
# [0 rows x 27 columns]

# %%
# It says that someone is not eligible if they're in atlanta, since they have their own ERA program. It looks like there are a couple recipients
# that are in atlanta, but very few
df[(df['city of atlanta']==True) & (df['case status']=='Paid')]
# Out:
#        row id  case id case status case: date created  case: program year  \
# 13432   19017    52600        Paid         08/03/2021                2021
# 14300   19041    52628        Paid         08/03/2021                2021
# 15909   18840    50236        Paid         08/02/2021                2021
# 16106   15755    49619        Paid         08/02/2021                2021
# 18599   17905    51383        Paid         08/02/2021                2021
# 19239   12005    41539        Paid         03/05/2021                2021
# 20419   19025    52610        Paid         08/03/2021                2021
# 20978   27922    60582        Paid         08/30/2021                2021
# 21179   28654    61418        Paid         09/02/2021                2021
# 21904   27802    60453        Paid         08/30/2021                2021
# 22321   24416    58936        Paid         08/26/2021                2021
# 24486   25630    59717        Paid         08/27/2021                2021
# 25361   23639    56817        Paid         08/16/2021                2021
# 25408   22773    58189        Paid         08/23/2021                2021
# 27839   23194    55687        Paid         08/11/2021                2021
# 29683   26450    62324        Paid         09/08/2021                2021
#
#        funding total amount  borrower 1: age   borrower 1: ethnicity  \
# 13432               7561.07             44.0                     NaN
# 14300               8925.32             23.0  Non-Hispanic or Latino
# 15909               8112.58             22.0  Non-Hispanic or Latino
# 16106               5008.15             33.0  Non-Hispanic or Latino
# 18599               6116.96             34.0  Non-Hispanic or Latino
# 19239               4400.00             30.0  Non-Hispanic or Latino
# 20419               9695.70             62.0  Non-Hispanic or Latino
# 20978               3900.00             35.0  Non-Hispanic or Latino
# 21179              21011.48             50.0  Non-Hispanic or Latino
# 21904              14312.41             61.0  Non-Hispanic or Latino
# 22321               7878.61             33.0  Non-Hispanic or Latino
# 24486              11700.00             51.0  Non-Hispanic or Latino
# 25361               8067.12             49.0  Non-Hispanic or Latino
# 25408               8067.12             32.0  Non-Hispanic or Latino
# 27839               3791.03             21.0  Non-Hispanic or Latino
# 29683               6607.36             29.0  Non-Hispanic or Latino
#
#       borrower 1: gender           borrower 1: race  ... out of county  \
# 13432             Female                      White  ...         False
# 14300               Male  Black or African American  ...         False
# 15909               Male  Black or African American  ...         False
# 16106             Female  Black or African American  ...         False
# 18599               Male  Black or African American  ...         False
# 19239                NaN                        NaN  ...         False
# 20419                NaN                      White  ...         False
# 20978             Female  Black or African American  ...         False
# 21179             Female  Black or African American  ...         False
# 21904             Female  Black or African American  ...         False
# 22321             Female  Black or African American  ...         False
# 24486             Female  Black or African American  ...         False
# 25361               Male  Black or African American  ...         False
# 25408             Female  Black or African American  ...         False
# 27839             Female  Black or African American  ...         False
# 29683             Female  Black or African American  ...         False
#
#        out of county text fulton service area  fulton service area text  \
# 13432       Fulton County               False   Non Fulton Service Area
# 14300       Fulton County               False   Non Fulton Service Area
# 15909       Fulton County               False   Non Fulton Service Area
# 16106       Fulton County               False   Non Fulton Service Area
# 18599       Fulton County               False   Non Fulton Service Area
# 19239       Fulton County               False   Non Fulton Service Area
# 20419       Fulton County               False   Non Fulton Service Area
# 20978       Fulton County               False   Non Fulton Service Area
# 21179       Fulton County               False   Non Fulton Service Area
# 21904       Fulton County               False   Non Fulton Service Area
# 22321       Fulton County               False   Non Fulton Service Area
# 24486       Fulton County               False   Non Fulton Service Area
# 25361       Fulton County               False   Non Fulton Service Area
# 25408       Fulton County               False   Non Fulton Service Area
# 27839       Fulton County               False   Non Fulton Service Area
# 29683       Fulton County               False   Non Fulton Service Area
#
#        check disbursement date  ams amount  days from creation to submitted  \
# 13432               10/18/2021     7561.07                              0.0
# 14300               09/30/2021     8925.32                              0.0
# 15909               09/16/2021     8112.58                              1.0
# 16106               08/11/2021     5008.15                              0.0
# 18599               10/22/2021    12233.92                              0.0
# 19239               07/21/2021     4400.00                             36.0
# 20419               11/04/2021     9695.70                              0.0
# 20978               09/09/2021     3900.00                              1.0
# 21179               09/29/2021    21011.48                              2.0
# 21904               11/09/2021    14312.41                              0.0
# 22321               10/05/2021    15517.69                             26.0
# 24486               10/20/2021    11700.00                              0.0
# 25361               12/09/2021     8067.12                              7.0
# 25408               12/09/2021     8067.12                              1.0
# 27839               09/30/2021     3791.03                             28.0
# 29683               10/26/2021     6607.36                              2.0
#
#        submit to disbursement duplicate case status 2
# 13432                    76.0     False          Paid
# 14300                    58.0     False          Paid
# 15909                    44.0     False          Paid
# 16106                     9.0     False          Paid
# 18599                    81.0     False          Paid
# 19239                   102.0     False          Paid
# 20419                    93.0     False          Paid
# 20978                     9.0     False          Paid
# 21179                    25.0     False          Paid
# 21904                    71.0     False          Paid
# 22321                    14.0     False          Paid
# 24486                    54.0     False          Paid
# 25361                   108.0     False          Paid
# 25408                   107.0     False          Paid
# 27839                    22.0     False          Paid
# 29683                    46.0     False          Paid
#
# [16 rows x 55 columns]

# %%
# I didn't know what this column it is. Looks like there is only one entry and can be dropped
df_appcomp['tenant code'].unique()
# Out:
# array(['ERAP-FULTONCOUNTYGA'], dtype=object)

# %%
df_appcomp.drop('tenant code', axis=1, inplace=True)
# Out:
# /home/jcummings/.local/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# Looks like it takes on average  100 days for someone who will get paid to know that they'll get paid
df_appcomp.groupby('case status').agg('mean')[['days from creation to submitted', 'submit to disbursement']]
# Out:
#              days from creation to submitted  submit to disbursement
# case status
# Denied                              7.436690              122.875000
# Paid                               12.497853               73.073132

# %% [markdown]
# ## Removing unresolved cases

# %%
# Making names more managable
rename_dictionary = {'case status': 'case status', 'case: date created': 'case created', 'borrower 1: age': 'age',
                     'borrower 1: ethnicity': 'ethnicity', 'borrower 1: gender': 'gender', 'borrower 1: race': 'race', 
                     'borrower_1_relationshiptoheadofhousehold': 'relation to hh', 'case: landlord case id': 'landlord case id', 
                     'household annual income': 'annual income', 'household size': 'household size', 'total assistance requested': 'assistance requested', 
                     'x': 'lat', 'y': 'long', 'zip_latitude': 'zip_lat', 'zip_longitude': 'zip_long', 'city of atlanta': 'in atl', 
                     'out of county': 'out of county', 'fulton service area': 'in fulton service area', 
                     'days from creation to submitted': 'days from creation to submitted', 
                     'submit to disbursement': 'days from submitted to disbursement', 'duplicate': 'duplicate'}
df_appcomp.rename(columns = rename_dictionary, inplace=True)
# Out:
# /home/jcummings/.local/lib/python3.6/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_appcomp.head()
# Out:
#    case status case created   age               ethnicity  gender  \
# 3       Denied   03/01/2021  38.0  Non-Hispanic or Latino    Male
# 4       Denied   03/01/2021  60.0                     NaN    Male
# 6       Denied   03/01/2021  38.0  Non-Hispanic or Latino  Female
# 8       Denied   03/01/2021  26.0                     NaN     NaN
# 10      Denied   03/01/2021  50.0  Non-Hispanic or Latino    Male
#
#                          race                         relation to hh  \
# 3   Black or African American                                   Self
# 4   Black or African American  Head of household's spouse or partner
# 6   Black or African American                                   Self
# 8                         NaN                                    NaN
# 10  Black or African American                                    NaN
#
#     landlord case id  annual income  household ami ratio  ...    zip_lat  \
# 3                NaN         3796.0                 6.55  ...  33.691741
# 4                NaN         8304.0                12.55  ...  33.625140
# 6                NaN        16800.0                29.00  ...  33.819890
# 8            48138.0        13656.0                23.57  ...  33.577868
# 10               NaN        39600.0                68.35  ...  33.625140
#
#      zip_long  in atl  out of county  in fulton service area  \
# 3  -84.247999     NaN           True                   False
# 4  -84.528002   False          False                    True
# 6  -84.356916    True          False                   False
# 8  -84.541992   False          False                    True
# 10 -84.528002     NaN           True                   False
#
#     days from creation to submitted  days from submitted to disbursement  \
# 3                               0.0                                  NaN
# 4                               2.0                                  NaN
# 6                               NaN                                  NaN
# 8                               0.0                                  NaN
# 10                              1.0                                  NaN
#
#     duplicate case status 2 case status numeric
# 3       False        Denied                 0.0
# 4       False        Denied                 0.0
# 6       False        Denied                 0.0
# 8       False        Denied                 0.0
# 10      False        Denied                 0.0
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Revisiting TODOs from initial notes

# %%
## Change to datetime
df_appcomp['case created'] = pd.to_datetime(df_appcomp['case created'])
# Out:
# /home/jcummings/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## Going to drop the landlord case id, not sure exactly what this indicates
df_appcomp.drop('landlord case id', axis = 1, inplace=True)
# Out:
# /home/jcummings/.local/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# Take another look at missing values
calculate_percent_missing(df_appcomp)
# Out:
#                                      percent_missing
# case status                                 0.000000
# case created                                0.000000
# age                                        12.442477
# ethnicity                                  22.118017
# gender                                     18.081202
# race                                       19.030698
# relation to hh                             25.321838
# annual income                              12.366750
# household ami ratio                        16.351139
# household ami ratio rounded                17.824897
# household size                             12.302674
# assistance requested                        0.000000
# total assistance approved                   0.000000
# lat                                        19.234578
# long                                       19.234578
# zip_lat                                     3.267898
# zip_long                                    3.267898
# in atl                                     24.191763
# out of county                              19.234578
# in fulton service area                     19.234578
# days from creation to submitted            23.894682
# days from submitted to disbursement        74.544184
# duplicate                                   0.000000
# case status 2                               0.000000
# case status numeric                         0.000000

# %%
# Check to see if case status 2 is a duplicate of case status

status_mask = df_appcomp['case status'] != df_appcomp['case status 2']
df_appcomp[status_mask]
# Out:
#       case status case created   age               ethnicity  gender  \
# 828        Denied   2021-03-01  33.0                     NaN  Female
# 1822       Denied   2021-03-01   NaN                     NaN     NaN
# 2028       Denied   2021-03-02  25.0  Non-Hispanic or Latino    Male
# 4772         Paid   2021-03-02  42.0  Non-Hispanic or Latino    Male
# 4851         Paid   2021-03-01  60.0  Non-Hispanic or Latino  Female
# 5187         Paid   2021-03-03  41.0  Non-Hispanic or Latino  Female
# 6193       Denied   2021-03-02  40.0  Non-Hispanic or Latino  Female
# 7642         Paid   2021-03-01  31.0  Non-Hispanic or Latino  Female
# 12914      Denied   2021-04-30   NaN                     NaN     NaN
# 13083        Paid   2021-03-05  29.0  Non-Hispanic or Latino  Female
# 14362      Denied   2021-03-15  55.0  Non-Hispanic or Latino  Female
# 16144        Paid   2021-03-08  44.0  Non-Hispanic or Latino  Female
# 16749        Paid   2021-03-08  48.0  Non-Hispanic or Latino    Male
# 17669      Denied   2021-03-15   NaN                     NaN     NaN
# 19749      Denied   2021-03-11   NaN                     NaN     NaN
# 19938      Denied   2021-03-24   NaN                     NaN     NaN
# 20121      Denied   2021-03-08   NaN                     NaN     NaN
#
#                             race  \
# 828             Refuse to Answer
# 1822                         NaN
# 2028   Black or African American
# 4772   Black or African American
# 4851   Black or African American
# 5187   Black or African American
# 6193   Black or African American
# 7642   Black or African American
# 12914                        NaN
# 13083  Black or African American
# 14362  Black or African American
# 16144                      White
# 16749  Black or African American
# 17669                        NaN
# 19749                        NaN
# 19938                        NaN
# 20121                        NaN
#
#                                           relation to hh  annual income  \
# 828                                                  NaN       50325.22
# 1822                                                 NaN            NaN
# 2028                                                Self         214.00
# 4772                                                 NaN       84642.00
# 4851                                                Self       12324.00
# 5187                                                Self       43680.00
# 6193                                                Self           0.00
# 7642                                                 NaN        8160.90
# 12914                                                NaN            NaN
# 13083                                               Self       48300.00
# 14362  Head of household's other relation member (oth...           0.00
# 16144                                               Self       27560.00
# 16749                                               Self       62100.00
# 17669                                                NaN            NaN
# 19749                                                NaN            NaN
# 19938                                                NaN            NaN
# 20121                                                NaN            NaN
#
#        household ami ratio  household ami ratio rounded  ...    zip_lat  \
# 828                  72.94                         80.0  ...  33.675432
# 1822                   NaN                          NaN  ...  33.757898
# 2028                  0.35                         30.0  ...  33.675432
# 4772                 90.89                          NaN  ...  34.027544
# 4851                 21.27                         30.0  ...  33.660123
# 5187                 72.35                         80.0  ...  33.979354
# 6193                  0.00                         30.0  ...  33.625140
# 7642                 10.96                         30.0  ...  33.586314
# 12914                  NaN                          NaN  ...  33.707026
# 13083                80.00                         80.0  ...  33.979354
# 14362                 0.00                         30.0  ...  33.726650
# 16144                41.64                         50.0  ...  33.979354
# 16749                80.00                         80.0  ...  33.979354
# 17669                  NaN                          NaN  ...  33.726650
# 19749                  NaN                          NaN  ...  33.625140
# 19938                  NaN                          NaN  ...  33.792701
# 20121                  NaN                          NaN  ...  33.707026
#
#         zip_long  in atl  out of county  in fulton service area  \
# 828   -84.461258   False          False                    True
# 1822  -84.432463     NaN            NaN                     NaN
# 2028  -84.461258   False          False                    True
# 4772  -84.246944   False          False                    True
# 4851  -84.388003   False          False                    True
# 5187  -84.333041   False          False                    True
# 6193  -84.528002   False          False                    True
# 7642  -84.618385   False          False                    True
# 12914 -84.538680    True          False                   False
# 13083 -84.333041   False          False                    True
# 14362 -84.426975     NaN            NaN                     NaN
# 16144 -84.333041   False          False                    True
# 16749 -84.333041   False          False                    True
# 17669 -84.426975     NaN            NaN                     NaN
# 19749 -84.528002   False          False                    True
# 19938 -84.447896    True          False                   False
# 20121 -84.538680     NaN            NaN                     NaN
#
#        days from creation to submitted  days from submitted to disbursement  \
# 828                              152.0                                  NaN
# 1822                               NaN                                  NaN
# 2028                             164.0                                  NaN
# 4772                             202.0                                 35.0
# 4851                             231.0                                 28.0
# 5187                             183.0                                 55.0
# 6193                               NaN                                  NaN
# 7642                             154.0                                 22.0
# 12914                              NaN                                  NaN
# 13083                            250.0                                 40.0
# 14362                              NaN                                  NaN
# 16144                            150.0                                 34.0
# 16749                            189.0                                 49.0
# 17669                              NaN                                  NaN
# 19749                              NaN                                  NaN
# 19938                              NaN                                  NaN
# 20121                              NaN                                  NaN
#
#       duplicate case status 2 case status numeric
# 828        True   Duplicate 2                 0.0
# 1822       True   Duplicate 2                 0.0
# 2028       True   Duplicate 2                 0.0
# 4772       True   Duplicate 2                 0.0
# 4851       True   Duplicate 2                 0.0
# 5187       True   Duplicate 2                 1.0
# 6193       True   Duplicate 2                 0.0
# 7642       True   Duplicate 2                 0.0
# 12914      True   Duplicate 2                 0.0
# 13083      True   Duplicate 2                 0.0
# 14362      True   Duplicate 2                 0.0
# 16144      True   Duplicate 2                 1.0
# 16749      True   Duplicate 2                 1.0
# 17669      True   Duplicate 2                 0.0
# 19749      True   Duplicate 2                 0.0
# 19938      True   Duplicate 2                 0.0
# 20121      True   Duplicate 2                 0.0
#
# [17 rows x 25 columns]

# %%
# Looks like they are all marked as duplicate. Checking
df_appcomp[status_mask]['duplicate'].unique()
# Out:
# array([ True])

# %%
# Since they are, and I planned on dropping all duplicates anyways, I don't have to worry about it after the next line of dropping the duplicate cases
duplicate_drop_mask = df_appcomp['duplicate']==False
df_appcomp = df_appcomp[duplicate_drop_mask]

# %%
df_appcomp.drop('case status 2', axis=1, inplace=True)
# Out:
# /home/jcummings/.local/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_appcomp.drop('duplicate', axis=1, inplace=True)

# %%
#It looks like there are some weird entries for assistance requested, with the minimum being negative. Going to remove that
df_appcomp.describe()
# Out:
#                 age  annual income  household ami ratio  \
# count  15020.000000   15033.000000         14349.000000
# mean      35.540080   20024.849655            31.060146
# std       13.779481   21868.155015            31.813843
# min      -77.000000       0.000000           -94.650000
# 25%       28.000000       0.000000             0.000000
# 50%       34.000000   13951.000000            23.010000
# 75%       43.000000   35460.000000            56.210000
# max      122.000000  445940.000000           517.410000
#
#        household ami ratio rounded  household size  assistance requested  \
# count                 14097.000000    15044.000000          1.715000e+04
# mean                     45.588423        1.926150          6.613630e+03
# std                      20.360583        1.301694          1.684464e+04
# min                      30.000000        1.000000         -1.154000e+03
# 25%                      30.000000        1.000000          2.000000e+02
# 50%                      30.000000        1.000000          3.900000e+03
# 75%                      60.000000        3.000000          8.070000e+03
# max                      80.000000       11.000000          1.275116e+06
#
#        total assistance approved           lat          long       zip_lat  \
# count               17150.000000  13852.000000  13852.000000  16589.000000
# mean                 1748.557522    -84.399511     33.718643     33.740424
# std                  3765.709225      1.930580      0.781025      0.133691
# min                     0.000000   -119.255492      0.000000     33.212721
# 25%                     0.000000    -84.495665     33.643630     33.641684
# 50%                     0.000000    -84.449080     33.708077     33.707026
# 75%                  1830.817500    -84.379041     33.782946     33.792701
# max                 63000.000000      0.000000     41.557467     34.253365
#
#            zip_long  days from creation to submitted  \
# count  16589.000000                     13056.000000
# mean     -84.442045                         9.028876
# std        0.101499                        29.629648
# min      -85.012164                         0.000000
# 25%      -84.528002                         0.000000
# 50%      -84.447896                         0.000000
# 75%      -84.382684                         3.000000
# max      -83.676030                       300.000000
#
#        days from submitted to disbursement  case status numeric
# count                          4363.000000         17150.000000
# mean                             73.221407             0.135685
# std                              52.991725             0.342464
# min                             -16.000000             0.000000
# 25%                              34.000000             0.000000
# 50%                              54.000000             0.000000
# 75%                             109.000000             0.000000
# max                             293.000000             1.000000

# %%
#Remove entries where assistance requested is very small
assist_req_drop = df_appcomp['assistance requested']>300
df_appcomp = df_appcomp[assist_req_drop]

# %%
# Looks like almost all of the missing entries for the columns are significantly reduced once we remove duplicates, and remove very small loan amounts
calculate_percent_missing(df_appcomp)
# Out:
#                                      percent_missing
# case status                                 0.000000
# case created                                0.000000
# age                                         0.078107
# ethnicity                                  10.724049
# gender                                      6.186050
# race                                        7.295165
# relation to hh                             14.395064
# annual income                               0.374912
# household ami ratio                         0.359291
# household ami ratio rounded                 2.202609
# household size                              0.288995
# assistance requested                        0.000000
# total assistance approved                   0.000000
# lat                                        23.150824
# long                                       23.150824
# zip_lat                                     2.616574
# zip_long                                    2.616574
# in atl                                     26.618761
# out of county                              23.150824
# in fulton service area                     23.150824
# days from creation to submitted             3.296102
# days from submitted to disbursement        66.125127
# case status numeric                         0.000000

# %%
# I'm going to do a reality check on the numerical variables making a pivot table of the numerical variables
# It is surprising that the annual income of the denied lenders is smaller than that of the approved. The household size is also larger, so maybe 
# if we look at it by houshold size as well that will make more sense
pd.pivot_table(df_appcomp, index=['case status numeric'],  values = df_appcomp.columns, aggfunc = np.nanmean)
# Out:
#                            age  annual income  assistance requested  \
# case status numeric
# 0.0                  35.220216   20305.983821           9695.302590
# 1.0                  37.240757   31617.800523           5084.373292
#
#                      days from creation to submitted  \
# case status numeric
# 0.0                                         8.163401
# 1.0                                        13.078246
#
#                      days from submitted to disbursement  household ami ratio  \
# case status numeric
# 0.0                                            81.015209            30.325707
# 1.0                                            65.992387            45.427232
#
#                      household ami ratio rounded  household size        lat  \
# case status numeric
# 0.0                                    44.952167        1.895215 -84.430582
# 1.0                                    54.492754        2.189983 -84.455273
#
#                           long  total assistance approved    zip_lat  \
# case status numeric
# 0.0                  33.731124                1188.789733  33.741029
# 1.0                  33.739890                7480.083021  33.750589
#
#                       zip_long
# case status numeric
# 0.0                 -84.439130
# 1.0                 -84.454134

# %%
# There are a lot of latitude and logitude data missing, but not a lot of zip_lat or zip_long 
# data missing. I'll drop the missing values, then create a column that is a string of their coordinate pairs
# Then I can one-hot encode on this column (after making sure there are not too many unique values)
# Another option could be to KMeans cluster on this, or grid the the county and assign each case to a grid cell
df_appcomp.dropna(subset=['zip_lat', 'zip_long'], inplace=True)

# %%
def to_string_round(row):
    row['zip_lat_str']  = "{:.1f}".format(round(row['zip_lat'],0))
    row['zip_long_str'] = "{:.1f}".format(round(row['zip_long'],0))
    row['zip_loc'] = row['zip_lat_str'] + ', ' + row['zip_long_str']
    return row

df_appcomp = df_appcomp.apply(to_string_round, axis=1)

# %%
len(df_appcomp['zip_loc'].unique())
# Out:
# 4

# %%
# All location except zip_loc are now unnecessary
df_appcomp.drop(['lat', 'long', 'zip_lat_str', 'zip_long_str', 'zip_lat', 'zip_long'], axis=1, inplace=True)

# %%
# Perhaps the large amount of NaN values somehow indicates that an application is incomplete in some way. If so, removing rows with NaNs should be of some assistance
# Let's start by removing any row with a null. 
# The result is still strange
df_appcomp.loc[df_appcomp['gender'].isnull(),'gender'] = 'unkown'
df_appcomp.loc[df_appcomp['race'].isnull(),'race'] = 'unkown'
df_appcomp.loc[df_appcomp['relation to hh'].isnull(),'relation to hh'] = 'unknown'
df_appcomp.loc[df_appcomp['ethnicity'].isnull(),'ethnicity'] = 'unkown'
df_appcomp.loc[df_appcomp['in atl'].isnull(),'in atl'] = 'unkown'
df_appcomp.loc[df_appcomp['out of county'].isnull(),'out of county'] = 'unkown'
calculate_percent_missing(df_appcomp)
# Out:
#                                      percent_missing
# case status                                 0.000000
# case created                                0.000000
# age                                         0.072185
# ethnicity                                   0.000000
# gender                                      0.000000
# race                                        0.000000
# relation to hh                              0.000000
# annual income                               0.368944
# household ami ratio                         0.360924
# household ami ratio rounded                 2.221688
# household size                              0.288739
# assistance requested                        0.000000
# total assistance approved                   0.000000
# in atl                                      0.000000
# out of county                               0.000000
# in fulton service area                     23.203401
# days from creation to submitted             3.240295
# days from submitted to disbursement        65.752326
# case status numeric                         0.000000
# zip_loc                                     0.000000

# %%
df_nonull = df_appcomp.dropna(subset=['annual income', 'household ami ratio', 'household size', 'out of county', 'household ami ratio rounded'])

# %%
calculate_percent_missing(df_nonull)
# Out:
#                                      percent_missing
# case status                                 0.000000
# case created                                0.000000
# age                                         0.008210
# ethnicity                                   0.000000
# gender                                      0.000000
# race                                        0.000000
# relation to hh                              0.000000
# annual income                               0.000000
# household ami ratio                         0.000000
# household ami ratio rounded                 0.000000
# household size                              0.000000
# assistance requested                        0.000000
# total assistance approved                   0.000000
# in atl                                      0.000000
# out of county                               0.000000
# in fulton service area                     23.635170
# days from creation to submitted             3.136032
# days from submitted to disbursement        65.717100
# case status numeric                         0.000000
# zip_loc                                     0.000000

# %%
pd.pivot_table(df_nonull, index=['case status'],  values = df_nonull.columns, aggfunc = np.mean)
# Out:
#                    age  annual income  assistance requested  \
# case status
# Denied       34.236478   17688.738674           8593.701168
# Paid         37.536643   29526.359369           9396.686454
#
#              case status numeric  days from creation to submitted  \
# case status
# Denied                  0.004779                         7.145065
# Paid                    0.520804                        12.213002
#
#              days from submitted to disbursement  household ami ratio  \
# case status
# Denied                                122.833333            26.793938
# Paid                                   71.898561            42.434686
#
#              household ami ratio rounded  household size  \
# case status
# Denied                         43.893850        1.810967
# Paid                           52.716312        2.220095
#
#              total assistance approved
# case status
# Denied                       79.762099
# Paid                       6605.415752

# %%
df_nonull
# Out:
#       case status case created   age               ethnicity  gender  \
# 3          Denied   2021-03-01  38.0  Non-Hispanic or Latino    Male
# 4          Denied   2021-03-01  60.0                  unkown    Male
# 6          Denied   2021-03-01  38.0  Non-Hispanic or Latino  Female
# 8          Denied   2021-03-01  26.0                  unkown  unkown
# 10         Denied   2021-03-01  50.0  Non-Hispanic or Latino    Male
# ...           ...          ...   ...                     ...     ...
# 34954      Denied   2021-11-29  15.0  Non-Hispanic or Latino  Female
# 34956        Paid   2021-10-29  50.0  Non-Hispanic or Latino  Female
# 34958        Paid   2021-10-12  29.0                  unkown  unkown
# 34959        Paid   2021-10-04  32.0  Non-Hispanic or Latino  Female
# 34962        Paid   2021-09-30  27.0  Non-Hispanic or Latino  Female
#
#                             race                         relation to hh  \
# 3      Black or African American                                   Self
# 4      Black or African American  Head of household's spouse or partner
# 6      Black or African American                                   Self
# 8                         unkown                                unknown
# 10     Black or African American                                unknown
# ...                          ...                                    ...
# 34954  Black or African American              Head of household's child
# 34956  Black or African American                                   Self
# 34958                     unkown                                unknown
# 34959  Black or African American                                   Self
# 34962  Black or African American              Head of household's child
#
#        annual income  household ami ratio  household ami ratio rounded  \
# 3             3796.0                 6.55                         30.0
# 4             8304.0                12.55                         30.0
# 6            16800.0                29.00                         30.0
# 8            13656.0                23.57                         30.0
# 10           39600.0                68.35                         80.0
# ...              ...                  ...                          ...
# 34954        48300.0                80.00                         80.0
# 34956        55200.0                80.00                         80.0
# 34958        55200.0                80.00                         80.0
# 34959        48300.0                80.00                         80.0
# 34962        74500.0                80.00                         80.0
#
#        household size  assistance requested  total assistance approved  \
# 3                 1.0               5254.38                       0.00
# 4                 2.0               5320.00                       0.00
# 6                 1.0              17991.89                       0.00
# 8                 1.0              10408.00                       0.00
# 10                1.0               3749.00                       0.00
# ...               ...                   ...                        ...
# 34954             1.0              38210.00                       0.00
# 34956             2.0               5131.01                    7659.01
# 34958             2.0               2881.28                    6132.89
# 34959             1.0               1916.00                    2656.99
# 34962             5.0              15804.00                    5268.50
#
#        in atl out of county in fulton service area  \
# 3      unkown          True                  False
# 4       False         False                   True
# 6        True         False                  False
# 8       False         False                   True
# 10     unkown          True                  False
# ...       ...           ...                    ...
# 34954  unkown        unkown                    NaN
# 34956  unkown        unkown                    NaN
# 34958  unkown        unkown                    NaN
# 34959  unkown        unkown                    NaN
# 34962  unkown        unkown                    NaN
#
#        days from creation to submitted  days from submitted to disbursement  \
# 3                                  0.0                                  NaN
# 4                                  2.0                                  NaN
# 6                                  NaN                                  NaN
# 8                                  0.0                                  NaN
# 10                                 1.0                                  NaN
# ...                                ...                                  ...
# 34954                              0.0                                  NaN
# 34956                              6.0                                  6.0
# 34958                             11.0                                 20.0
# 34959                              0.0                                 31.0
# 34962                              0.0                                 81.0
#
#        case status numeric      zip_loc
# 3                      0.0  34.0, -84.0
# 4                      0.0  34.0, -85.0
# 6                      0.0  34.0, -84.0
# 8                      0.0  34.0, -85.0
# 10                     0.0  34.0, -85.0
# ...                    ...          ...
# 34954                  0.0  34.0, -85.0
# 34956                  1.0  34.0, -85.0
# 34958                  1.0  34.0, -84.0
# 34959                  1.0  34.0, -84.0
# 34962                  0.0  34.0, -84.0
#
# [12181 rows x 20 columns]

# %%
# Looks like we at about 9300 entries entries after requiring a minimum age (which was -51 for some reason?)
df_nonull = df_nonull[df_nonull['age']>18]
df_nonull.describe()
# Out:
#                 age  annual income  household ami ratio  \
# count  11193.000000   11193.000000         11193.000000
# mean      37.629590   22282.235101            33.003170
# std       11.444923   20904.245537            30.268585
# min       19.000000       0.000000             0.000000
# 25%       29.000000     794.000000             1.210000
# 50%       35.000000   18200.000000            27.140000
# 75%       44.000000   40000.000000            59.690000
# max      122.000000   91050.000000            80.000000
#
#        household ami ratio rounded  household size  assistance requested  \
# count                 11193.000000    11193.000000          1.119300e+04
# mean                     47.373358        1.932636          8.961520e+03
# std                      20.827195        1.309066          1.985270e+04
# min                      30.000000        1.000000          3.038000e+02
# 25%                      30.000000        1.000000          3.260000e+03
# 50%                      30.000000        1.000000          5.521000e+03
# 75%                      60.000000        3.000000          1.077592e+04
# max                      80.000000       11.000000          1.275116e+06
#
#        total assistance approved  days from creation to submitted  \
# count               11193.000000                     10851.000000
# mean                 2468.081755                         9.169754
# std                  4251.074005                        29.796993
# min                     0.000000                         0.000000
# 25%                     0.000000                         0.000000
# 50%                     0.000000                         0.000000
# 75%                  4453.470000                         3.000000
# max                 63000.000000                       291.000000
#
#        days from submitted to disbursement  case status numeric
# count                          4037.000000         11193.000000
# mean                             72.484518             0.193335
# std                              52.196141             0.394931
# min                             -16.000000             0.000000
# 25%                              34.000000             0.000000
# 50%                              53.000000             0.000000
# 75%                             106.000000             0.000000
# max                             293.000000             1.000000

# %%
#dropping total assistance approved  for obvious data leakage reasons, as well as assistance requested

# %%
pd.pivot_table(df_nonull, index=['case status numeric'],  values = df_nonull.columns, aggfunc = np.nanmean)
# Out:
#                            age  annual income  assistance requested  \
# case status numeric
# 0.0                  37.536937   20138.481230           9895.584195
# 1.0                  38.016174   31226.760841           5064.261248
#
#                      days from creation to submitted  \
# case status numeric
# 0.0                                         8.203407
# 1.0                                        13.048983
#
#                      days from submitted to disbursement  household ami ratio  \
# case status numeric
# 0.0                                            80.492843            30.137660
# 1.0                                            64.957232            44.959127
#
#                      household ami ratio rounded  household size  \
# case status numeric
# 0.0                                    45.600842        1.876509
# 1.0                                    54.768946        2.166821
#
#                      total assistance approved
# case status numeric
# 0.0                                1279.541263
# 1.0                                7427.107680

# %%
df_nonull['race'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
from random import randrange
from sklearn.model_selection import train_test_split

# %%
df_nonull.head()
# Out:
#    case status case created   age               ethnicity  gender  \
# 3       Denied   2021-03-01  38.0  Non-Hispanic or Latino    Male
# 4       Denied   2021-03-01  60.0                  unkown    Male
# 6       Denied   2021-03-01  38.0  Non-Hispanic or Latino  Female
# 8       Denied   2021-03-01  26.0                  unkown  unkown
# 10      Denied   2021-03-01  50.0  Non-Hispanic or Latino    Male
#
#                          race                         relation to hh  \
# 3   Black or African American                                   Self
# 4   Black or African American  Head of household's spouse or partner
# 6   Black or African American                                   Self
# 8                      unkown                                unknown
# 10  Black or African American                                unknown
#
#     annual income  household ami ratio  household ami ratio rounded  \
# 3          3796.0                 6.55                         30.0
# 4          8304.0                12.55                         30.0
# 6         16800.0                29.00                         30.0
# 8         13656.0                23.57                         30.0
# 10        39600.0                68.35                         80.0
#
#     household size  assistance requested  total assistance approved  in atl  \
# 3              1.0               5254.38                        0.0  unkown
# 4              2.0               5320.00                        0.0   False
# 6              1.0              17991.89                        0.0    True
# 8              1.0              10408.00                        0.0   False
# 10             1.0               3749.00                        0.0  unkown
#
#    out of county in fulton service area  days from creation to submitted  \
# 3           True                  False                              0.0
# 4          False                   True                              2.0
# 6          False                  False                              NaN
# 8          False                   True                              0.0
# 10          True                  False                              1.0
#
#     days from submitted to disbursement  case status numeric      zip_loc
# 3                                   NaN                  0.0  34.0, -84.0
# 4                                   NaN                  0.0  34.0, -85.0
# 6                                   NaN                  0.0  34.0, -84.0
# 8                                   NaN                  0.0  34.0, -85.0
# 10                                  NaN                  0.0  34.0, -85.0

# %%
df_nonull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11193 entries, 3 to 34962
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   case status                          11193 non-null  object
#  1   case created                         11193 non-null  datetime64[ns]
#  2   age                                  11193 non-null  float64
#  3   ethnicity                            11193 non-null  object
#  4   gender                               11193 non-null  object
#  5   race                                 11193 non-null  object
#  6   relation to hh                       11193 non-null  object
#  7   annual income                        11193 non-null  float64
#  8   household ami ratio                  11193 non-null  float64
#  9   household ami ratio rounded          11193 non-null  float64
#  10  household size                       11193 non-null  float64
#  11  assistance requested                 11193 non-null  float64
#  12  total assistance approved            11193 non-null  float64
#  13  in atl                               11193 non-null  object
#  14  out of county                        11193 non-null  object
#  15  in fulton service area               8553 non-null   object
#  16  days from creation to submitted      10851 non-null  float64
#  17  days from submitted to disbursement  4037 non-null   float64
#  18  case status numeric                  11193 non-null  float64
#  19  zip_loc                              11193 non-null  object
# dtypes: datetime64[ns](1), float64(10), object(9)
# memory usage: 1.8+ MB

# %%
target = 'case status numeric'
num = ['age', 'household ami ratio', 'household size']
cat = ['ethnicity', 'gender', 'race', 'relation to hh', 'in atl', 'out of county'] #, 'zip_loc'
from sklearn.preprocessing import StandardScaler, MinMaxScaler #scaling the parameters
ss = StandardScaler()
cols_to_scale = num # cols not included: 'age', 'pregnancies', 'glucose', 'bloodpressure', 'insulin', 'bmi', 'diabetespedigreefunction',  'bloodpressure','skinthickness'
#pd.pivot_table(df, index=['outcome'],  values = df.columns, aggfunc = np.mean)
df_scaled = pd.DataFrame(ss.fit_transform(df_nonull[cols_to_scale]), index=df_nonull.index, columns=cols_to_scale)
df_scaled[target] = df_nonull[target]
pd.pivot_table(df_scaled, index=['case status numeric'],  values = df_scaled.columns, aggfunc = np.mean)
# Out:
#                           age  household ami ratio  household size
# case status numeric
# 0.0                 -0.008096            -0.094674       -0.042878
# 1.0                  0.033779             0.395013        0.178902

# %%
df_cat = df_nonull[cat]
df_cat_encoded = pd.get_dummies(df_cat, drop_first = True)
df_cat_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11193 entries, 3 to 34962
# Data columns (total 24 columns):
#  #   Column                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                          --------------  -----
#  0   ethnicity_Non-Hispanic or Latino                                                                11193 non-null  uint8
#  1   ethnicity_Refuse to Answer                                                                      11193 non-null  uint8
#  2   ethnicity_unkown                                                                                11193 non-null  uint8
#  3   gender_Gender Non-Conforming                                                                    11193 non-null  uint8
#  4   gender_Male                                                                                     11193 non-null  uint8
#  5   gender_Trans Female (Male to Female)                                                            11193 non-null  uint8
#  6   gender_Trans Male (Female to Male)                                                              11193 non-null  uint8
#  7   gender_unkown                                                                                   11193 non-null  uint8
#  8   race_Asian                                                                                      11193 non-null  uint8
#  9   race_Black or African American                                                                  11193 non-null  uint8
#  10  race_Multi-Racial                                                                               11193 non-null  uint8
#  11  race_Native Hawaiian or Other Pacific Islander                                                  11193 non-null  uint8
#  12  race_Refuse to Answer                                                                           11193 non-null  uint8
#  13  race_White                                                                                      11193 non-null  uint8
#  14  race_unkown                                                                                     11193 non-null  uint8
#  15  relation to hh_Head of household's other relation member (other relation to head of household)  11193 non-null  uint8
#  16  relation to hh_Head of household's spouse or partner                                            11193 non-null  uint8
#  17  relation to hh_Other: non-relation member                                                       11193 non-null  uint8
#  18  relation to hh_Self                                                                             11193 non-null  uint8
#  19  relation to hh_unknown                                                                          11193 non-null  uint8
#  20  in atl_True                                                                                     11193 non-null  uint8
#  21  in atl_unkown                                                                                   11193 non-null  uint8
#  22  out of county_True                                                                              11193 non-null  uint8
#  23  out of county_unkown                                                                            11193 non-null  uint8
# dtypes: uint8(24)
# memory usage: 349.8 KB

# %%
#df_cat_encoded.drop(['ethnicity_Non-Hispanic or Latino', 'gender_Male', 'race_Black or African American', 'relation to hh_Self', 'in atl_False', 'out of county_False'], axis=1, inplace=True)

# %%
df_cat_encoded.head()
# Out:
#     ethnicity_Non-Hispanic or Latino  ethnicity_Refuse to Answer  \
# 3                                  1                           0
# 4                                  0                           0
# 6                                  1                           0
# 8                                  0                           0
# 10                                 1                           0
#
#     ethnicity_unkown  gender_Gender Non-Conforming  gender_Male  \
# 3                  0                             0            1
# 4                  1                             0            1
# 6                  0                             0            0
# 8                  1                             0            0
# 10                 0                             0            1
#
#     gender_Trans Female (Male to Female)  gender_Trans Male (Female to Male)  \
# 3                                      0                                   0
# 4                                      0                                   0
# 6                                      0                                   0
# 8                                      0                                   0
# 10                                     0                                   0
#
#     gender_unkown  race_Asian  race_Black or African American  ...  \
# 3               0           0                               1  ...
# 4               0           0                               1  ...
# 6               0           0                               1  ...
# 8               1           0                               0  ...
# 10              0           0                               1  ...
#
#     race_unkown  \
# 3             0
# 4             0
# 6             0
# 8             1
# 10            0
#
#     relation to hh_Head of household's other relation member (other relation to head of household)  \
# 3                                                   0
# 4                                                   0
# 6                                                   0
# 8                                                   0
# 10                                                  0
#
#     relation to hh_Head of household's spouse or partner  \
# 3                                                   0
# 4                                                   1
# 6                                                   0
# 8                                                   0
# 10                                                  0
#
#     relation to hh_Other: non-relation member  relation to hh_Self  \
# 3                                           0                    1
# 4                                           0                    0
# 6                                           0                    1
# 8                                           0                    0
# 10                                          0                    0
#
#     relation to hh_unknown  in atl_True  in atl_unkown  out of county_True  \
# 3                        0            0              1                   1
# 4                        0            0              0                   0
# 6                        0            1              0                   0
# 8                        1            0              0                   0
# 10                       1            0              1                   1
#
#     out of county_unkown
# 3                      0
# 4                      0
# 6                      0
# 8                      0
# 10                     0
#
# [5 rows x 24 columns]

# %%
df_rejoined = pd.concat([df_scaled, df_cat_encoded], axis=1)
y = df_rejoined.pop('case status numeric')
df_rejoined.info()
y=y.astype('int')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11193 entries, 3 to 34962
# Data columns (total 27 columns):
#  #   Column                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                          --------------  -----
#  0   age                                                                                             11193 non-null  float64
#  1   household ami ratio                                                                             11193 non-null  float64
#  2   household size                                                                                  11193 non-null  float64
#  3   ethnicity_Non-Hispanic or Latino                                                                11193 non-null  uint8
#  4   ethnicity_Refuse to Answer                                                                      11193 non-null  uint8
#  5   ethnicity_unkown                                                                                11193 non-null  uint8
#  6   gender_Gender Non-Conforming                                                                    11193 non-null  uint8
#  7   gender_Male                                                                                     11193 non-null  uint8
#  8   gender_Trans Female (Male to Female)                                                            11193 non-null  uint8
#  9   gender_Trans Male (Female to Male)                                                              11193 non-null  uint8
#  10  gender_unkown                                                                                   11193 non-null  uint8
#  11  race_Asian                                                                                      11193 non-null  uint8
#  12  race_Black or African American                                                                  11193 non-null  uint8
#  13  race_Multi-Racial                                                                               11193 non-null  uint8
#  14  race_Native Hawaiian or Other Pacific Islander                                                  11193 non-null  uint8
#  15  race_Refuse to Answer                                                                           11193 non-null  uint8
#  16  race_White                                                                                      11193 non-null  uint8
#  17  race_unkown                                                                                     11193 non-null  uint8
#  18  relation to hh_Head of household's other relation member (other relation to head of household)  11193 non-null  uint8
#  19  relation to hh_Head of household's spouse or partner                                            11193 non-null  uint8
#  20  relation to hh_Other: non-relation member                                                       11193 non-null  uint8
#  21  relation to hh_Self                                                                             11193 non-null  uint8
#  22  relation to hh_unknown                                                                          11193 non-null  uint8
#  23  in atl_True                                                                                     11193 non-null  uint8
#  24  in atl_unkown                                                                                   11193 non-null  uint8
#  25  out of county_True                                                                              11193 non-null  uint8
#  26  out of county_unkown                                                                            11193 non-null  uint8
# dtypes: float64(3), uint8(24)
# memory usage: 612.1 KB

# %%
y.mean()
# Out:
# 0.19333512016438845

# %%
X_train, X_test, y_train, y_test = train_test_split(df_rejoined, y, test_size=TEST_FRACTION, random_state = RAND_STATE)

# %%
from sklearn.linear_model import LogisticRegression
grid_values_log = {'penalty': ['l2'], 'C': np.logspace(-3, 4, 100), 'solver': ['liblinear']}
clf_log = LogisticRegression(random_state = RAND_STATE)
grid_clf_log = GridSearchCV(clf_log, param_grid=grid_values_log, cv=CV, scoring=OPT_ON, n_jobs=N_JOBS, verbose=2)
grid_clf_log.fit(X_train, y_train)
# Out:
# Fitting 7 folds for each of 100 candidates, totalling 700 fits
# GridSearchCV(cv=7, estimator=LogisticRegression(random_state=0), n_jobs=7,
#              param_grid={'C': array([1.00000000e-03, 1.17681195e-03, 1.38488637e-03, 1.62975083e-03,
#        1.91791026e-03, 2.25701972e-03, 2.65608778e-03, 3.12571585e-03,
#        3.67837977e-03, 4.32876128e-03, 5.09413801e-03, 5.99484250e-03,
#        7.05480231e-03, 8.30217568e-03, 9.77009957e-03, 1.14975700e-02,
#        1.35304777e-02,...
#        4.53487851e+02, 5.33669923e+02, 6.28029144e+02, 7.39072203e+02,
#        8.69749003e+02, 1.02353102e+03, 1.20450354e+03, 1.41747416e+03,
#        1.66810054e+03, 1.96304065e+03, 2.31012970e+03, 2.71858824e+03,
#        3.19926714e+03, 3.76493581e+03, 4.43062146e+03, 5.21400829e+03,
#        6.13590727e+03, 7.22080902e+03, 8.49753436e+03, 1.00000000e+04]),
#                          'penalty': ['l2'], 'solver': ['liblinear']},
#              scoring='f1', verbose=2)

# %%
print('Best Params: {}, \n Best score: {}'.format(grid_clf_log.best_params_, grid_clf_log.best_score_))
# Out:
# Best Params: {'C': 28.48035868435799, 'penalty': 'l2', 'solver': 'liblinear'},
#  Best score: 0.009659688805794792

# %%
summary_of_model(grid_clf_log, X_train, X_test, y_train, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.89      2259
#            1       0.50      0.01      0.01       540
#
#     accuracy                           0.81      2799
#    macro avg       0.65      0.50      0.45      2799
# weighted avg       0.75      0.81      0.72      2799
#
# Recall on the training set: 0.01
# Accuracy on the training set: 0.81
# Recall on the test set: 0.01
# Accuracy on the test set: 0.81
# [[2255    4]
#  [ 536    4]]

# %%
model = LogisticRegression(C= 1.7886495290574351, penalty='l2', solver='liblinear')
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.7886495290574351, solver='liblinear')

# %%
coef_list = pd.DataFrame(list(zip(df_rejoined.columns, model.coef_[0])))

# %%
coef_list.sort_values(1, ascending=False)
# Out:
#                                                     0         1
# 15                              race_Refuse to Answer  0.723775
# 1                                 household ami ratio  0.609506
# 12                     race_Black or African American  0.353292
# 26                               out of county_unkown  0.335930
# 13                                  race_Multi-Racial  0.320704
# 5                                    ethnicity_unkown  0.260766
# 2                                      household size  0.249696
# 17                                        race_unkown  0.227827
# 22                             relation to hh_unknown  0.170675
# 3                    ethnicity_Non-Hispanic or Latino  0.112959
# 14     race_Native Hawaiian or Other Pacific Islander  0.083500
# 6                        gender_Gender Non-Conforming  0.074296
# 16                                         race_White  0.063861
# 21                                relation to hh_Self  0.060834
# 0                                                 age  0.046745
# 8                gender_Trans Female (Male to Female)  0.029111
# 7                                         gender_Male  0.006762
# 11                                         race_Asian -0.012700
# 18  relation to hh_Head of household's other relat... -0.032941
# 4                          ethnicity_Refuse to Answer -0.118810
# 10                                      gender_unkown -0.190404
# 9                  gender_Trans Male (Female to Male) -0.335884
# 20          relation to hh_Other: non-relation member -0.660101
# 19  relation to hh_Head of household's spouse or p... -0.715761
# 24                                      in atl_unkown -2.068449
# 25                                 out of county_True -2.404379
# 23                                        in atl_True -5.539428

# %%
# Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
grid_values_boost = {'n_estimators': [100, 200, 300, 400, 500],
                     'learning_rate': [1e-3, 2e-3, 3e-3, 4e-3, 5e-3], 
                     'max_depth': [2, 3]}
clf_boost = GradientBoostingClassifier(random_state = RAND_STATE)
grid_clf_boost = GridSearchCV(clf_boost, param_grid=grid_values_boost, cv=CV, scoring=OPT_ON, n_jobs=N_JOBS, verbose=2)
grid_clf_boost.fit(X_train, y_train)
# Out:
# Fitting 7 folds for each of 50 candidates, totalling 350 fits
# GridSearchCV(cv=7, estimator=GradientBoostingClassifier(random_state=0),
#              n_jobs=7,
#              param_grid={'learning_rate': [0.001, 0.002, 0.003, 0.004, 0.005],
#                          'max_depth': [2, 3],
#                          'n_estimators': [100, 200, 300, 400, 500]},
#              scoring='f1', verbose=2)

# %%
print('Best Params: {}, \n Best score: {}'.format(grid_clf_boost.best_params_, grid_clf_boost.best_score_))

# %%
# Out:
# Best Params: {'learning_rate': 0.002, 'max_depth': 2, 'n_estimators': 500},
#  Best score: 0.7764194888837261

# %%
print(OPT_ON)
# Out:
# f1

# %%
summary_of_model(grid_clf_boost, X_train, X_test, y_train, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82      1790
#            1       0.67      0.74      0.70      1009
#
#     accuracy                           0.78      2799
#    macro avg       0.76      0.77      0.76      2799
# weighted avg       0.78      0.78      0.78      2799
#
# Recall on the training set: 0.76
# Accuracy on the training set: 0.79
# Recall on the test set: 0.74
# Accuracy on the test set: 0.78
# [[1427  363]
#  [ 264  745]]

# %%
clf_boost = GradientBoostingClassifier(learning_rate=0.002, max_depth= 2, n_estimators=500)

# %%
from keras import backend as K
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras.layers as tfl
from tensorflow.python.keras.utils.vis_utils import plot_model
from keras.layers.merge import concatenate

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation
from tensorflow.keras import Model

# %%
def create_model():
    #Create the base model

    inputs = tf.keras.Input(shape=X_train.shape[1])
    x = tf.keras.layers.Dense(512, activation='relu')(inputs)
    x1 = tf.keras.layers.Dense(256, activation='relu')(x)
    x = tf.keras.layers.Dense(256, activation='relu')(x1)
    merge = concatenate([x1, x])
    x1 = tf.keras.layers.Dense(256, activation='relu')(merge)
    x  = tf.keras.layers.Dense(256, activation='relu')(x1)
    merge = concatenate([x1, x])
    x1 = tf.keras.layers.Dense(256, activation='relu')(merge)
    x  = tf.keras.layers.Dense(256, activation='relu')(x1)
    merge = concatenate([x1, x])
    x1 = tf.keras.layers.Dense(256, activation='relu')(merge)
    x  = tf.keras.layers.Dense(256, activation='relu')(x1)
    merge = concatenate([x1, x])
    x1 = tf.keras.layers.Dense(256, activation='relu')(merge)
    x  = tf.keras.layers.Dense(256, activation='relu')(x1)
    merge = concatenate([x1, x])    
    x = tf.keras.layers.Dense(1, activation='sigmoid')(x)
    return Model(inputs, x) #start model at base_model inputs so we don't have to preprocess every time

DENSE = 32
model = create_model()

# %%
model.compile(optimizer='adam', 
              loss='binary_crossentropy', 
              metrics=['accuracy'])

# %%
NUM_EPOCHS = 15
history = model.fit(X_train, y_train, epochs = NUM_EPOCHS)
# Out:
# Epoch 1/15
# 201/201 [==============================] - 2s 7ms/step - loss: 0.4030 - accuracy: 0.7878
# Epoch 2/15
# 201/201 [==============================] - 1s 6ms/step - loss: 0.3751 - accuracy: 0.8089
# Epoch 3/15
# 201/201 [==============================] - 1s 6ms/step - loss: 0.3676 - accuracy: 0.8138
# Epoch 4/15
# 201/201 [==============================] - 1s 7ms/step - loss: 0.3677 - accuracy: 0.8142
# Epoch 5/15
# 201/201 [==============================] - 1s 7ms/step - loss: 0.3614 - accuracy: 0.8162
# Epoch 6/15
# 201/201 [==============================] - 1s 7ms/step - loss: 0.3613 - accuracy: 0.8159
# Epoch 7/15
# 201/201 [==============================] - 1s 7ms/step - loss: 0.3555 - accuracy: 0.8199
# Epoch 8/15
# 201/201 [==============================] - 1s 7ms/step - loss: 0.3547 - accuracy: 0.8190
# Epoch 9/15
# 201/201 [==============================] - 1s 7ms/step - loss: 0.3487 - accuracy: 0.8235
# Epoch 10/15
# 201/201 [==============================] - 1s 6ms/step - loss: 0.3520 - accuracy: 0.8235
# Epoch 11/15
# 201/201 [==============================] - 1s 7ms/step - loss: 0.3484 - accuracy: 0.8241
# Epoch 12/15
# 201/201 [==============================] - 1s 7ms/step - loss: 0.3465 - accuracy: 0.8252
# Epoch 13/15
# 201/201 [==============================] - 1s 7ms/step - loss: 0.3428 - accuracy: 0.8232
# Epoch 14/15
# 201/201 [==============================] - 1s 6ms/step - loss: 0.3401 - accuracy: 0.8274
# Epoch 15/15
# 201/201 [==============================] - 1s 7ms/step - loss: 0.3376 - accuracy: 0.8268

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print('Test accuracy :', accuracy)
# Out:
# 67/67 [==============================] - 0s 1ms/step - loss: 0.3921 - accuracy: 0.8079
# Test accuracy : 0.8078541159629822

# %% [markdown]
# # Linear Regression
#
# Now that we have a reasonable predictor if someone will receive a loan, let's build a regression model that will predict how much assistance one will received

# %%
df_assistance = df_nonull[df_nonull['total assistance approved']>0]
df_assistance.dropna(subset = ['days from creation to submitted', 'days from submitted to disbursement'], inplace=True)
df_assistance['total wait time'] = df_assistance['days from creation to submitted'] + df_assistance['days from submitted to disbursement']
calculate_percent_missing(df_assistance)
# Out:
# /home/jcummings/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/jcummings/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                      percent_missing
# case status                                 0.000000
# case created                                0.000000
# age                                         0.000000
# ethnicity                                   0.000000
# gender                                      0.000000
# race                                        0.000000
# relation to hh                              0.000000
# annual income                               0.000000
# household ami ratio                         0.000000
# household ami ratio rounded                 0.000000
# household size                              0.000000
# assistance requested                        0.000000
# total assistance approved                   0.000000
# in atl                                      0.000000
# out of county                               0.000000
# in fulton service area                     24.949239
# days from creation to submitted             0.000000
# days from submitted to disbursement         0.000000
# case status numeric                         0.000000
# zip_loc                                     0.000000
# total wait time                             0.000000

# %%
df_assistance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3940 entries, 46 to 34962
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   case status                          3940 non-null   object
#  1   case created                         3940 non-null   datetime64[ns]
#  2   age                                  3940 non-null   float64
#  3   ethnicity                            3940 non-null   object
#  4   gender                               3940 non-null   object
#  5   race                                 3940 non-null   object
#  6   relation to hh                       3940 non-null   object
#  7   annual income                        3940 non-null   float64
#  8   household ami ratio                  3940 non-null   float64
#  9   household ami ratio rounded          3940 non-null   float64
#  10  household size                       3940 non-null   float64
#  11  assistance requested                 3940 non-null   float64
#  12  total assistance approved            3940 non-null   float64
#  13  in atl                               3940 non-null   object
#  14  out of county                        3940 non-null   object
#  15  in fulton service area               2957 non-null   object
#  16  days from creation to submitted      3940 non-null   float64
#  17  days from submitted to disbursement  3940 non-null   float64
#  18  case status numeric                  3940 non-null   float64
#  19  zip_loc                              3940 non-null   object
#  20  total wait time                      3940 non-null   float64
# dtypes: datetime64[ns](1), float64(11), object(9)
# memory usage: 677.2+ KB

# %%
df_assistance['ratio_received'] = df_assistance['total assistance approved']/df_assistance['assistance requested']
# Out:
# /home/jcummings/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
target = 'total assistance approved'

# %%
df_assistance.describe()
# Out:
#                age  annual income  household ami ratio  \
# count  3940.000000    3940.000000          3940.000000
# mean     38.425635   29492.310386            42.483421
# std      10.999079   20472.561371            28.414230
# min      19.000000       0.000000             0.000000
# 25%      30.000000   12960.000000            19.052500
# 50%      36.000000   27064.000000            39.330000
# 75%      45.000000   48300.000000            78.162500
# max      86.000000   91050.000000            80.000000
#
#        household ami ratio rounded  household size  assistance requested  \
# count                  3940.000000     3940.000000           3940.000000
# mean                     52.761421        2.196701           9440.866168
# std                      21.112471        1.386527          18246.921904
# min                      30.000000        1.000000            305.080000
# 25%                      30.000000        1.000000           3752.250000
# 50%                      50.000000        2.000000           5979.670000
# 75%                      80.000000        3.000000          10533.870000
# max                      80.000000        9.000000         893779.000000
#
#        total assistance approved  days from creation to submitted  \
# count                3940.000000                      3940.000000
# mean                 6740.721873                        12.271320
# std                  4510.033765                        34.148493
# min                    46.740000                         0.000000
# 25%                  4090.990000                         0.000000
# 50%                  5734.795000                         0.000000
# 75%                  7800.000000                         6.000000
# max                 63000.000000                       253.000000
#
#        days from submitted to disbursement  case status numeric  \
# count                          3940.000000          3940.000000
# mean                             70.691117             0.998731
# std                              51.308126             0.035605
# min                             -16.000000             0.000000
# 25%                              33.000000             1.000000
# 50%                              52.000000             1.000000
# 75%                             101.000000             1.000000
# max                             293.000000             1.000000
#
#        total wait time  ratio_received
# count      3940.000000     3940.000000
# mean         82.962437        1.194958
# std          57.119345        1.122044
# min           8.000000        0.004986
# 25%          40.000000        0.633026
# 50%          63.000000        1.000000
# 75%         122.000000        1.436156
# max         294.000000       20.229125

# %%
# Looks like a lot of people receive more money than requested and the distribution is centered at 1.0
sns.histplot(data=df_assistance, x=target, kde=True)
# Out:
# <AxesSubplot:xlabel='total assistance approved', ylabel='Count'>

# %%
sns.regplot(data = df_assistance, x = 'age', y = target)
# Out:
# <AxesSubplot:xlabel='age', ylabel='total assistance approved'>

# %%
sns.regplot(data = df_assistance, x = 'annual income', y = target)
# Out:
# <AxesSubplot:xlabel='annual income', ylabel='total assistance approved'>

# %%
df_assistance = df_assistance[df_assistance['household size']>0]
df_assistance['income per hh mem'] = df_assistance['annual income']/df_assistance['household size']
sns.regplot(data = df_assistance, x = 'income per hh mem', y = target)
# Out:
# <AxesSubplot:xlabel='income per hh mem', ylabel='total assistance approved'>

# %%
sns.regplot(data = df_assistance, x = 'assistance requested', y = target)
# Out:
# <AxesSubplot:xlabel='assistance requested', ylabel='total assistance approved'>

# %%
df_assistance['ami per num in house'] = df_assistance['household ami ratio']/df_assistance['household size']
df_assistance.dropna(subset=['ami per num in house'], inplace=True)

# %%
sns.regplot(data = df_assistance, x = 'ami per num in house', y = target)
# Out:
# <AxesSubplot:xlabel='ami per num in house', ylabel='total assistance approved'>

# %%
num = ['age', 'income per hh mem', 'assistance requested']
cat = ['ethnicity', 'gender', 'race', 'relation to hh', 'in atl', 'out of county']
from sklearn.preprocessing import StandardScaler, MinMaxScaler #scaling the parameters
ss = StandardScaler()
cols_to_scale = num # cols not included: 'age', 'pregnancies', 'glucose', 'bloodpressure', 'insulin', 'bmi', 'diabetespedigreefunction',  'bloodpressure','skinthickness'
#pd.pivot_table(df, index=['outcome'],  values = df.columns, aggfunc = np.mean)
df_scaled = pd.DataFrame(ss.fit_transform(df_assistance[cols_to_scale]), index=df_assistance.index, columns=cols_to_scale)
df_scaled[target] = df_assistance[target]

# %%
df_scaled
# Out:
#             age  income per hh mem  assistance requested  \
# 46     0.779652          -0.836964             -0.216044
# 51    -1.311698           0.789267             -0.248559
# 565    1.143365          -0.183561             -0.101941
# 630    0.143154          -0.198350             -0.052740
# 636   -0.129630          -1.058596             -0.435245
# ...         ...                ...                   ...
# 34947  0.779652           0.206269             -0.062532
# 34956  1.052437           0.670033             -0.236226
# 34958 -0.857056           0.670033             -0.359536
# 34959 -0.584272           2.061324             -0.412443
# 34962 -1.038913          -0.183561              0.348768
#
#        total assistance approved
# 46                       5672.17
# 51                       4357.91
# 565                      9281.00
# 630                      8478.65
# 636                      1509.00
# ...                          ...
# 34947                   14763.72
# 34956                    7659.01
# 34958                    6132.89
# 34959                    2656.99
# 34962                    5268.50
#
# [3940 rows x 4 columns]

# %%
df_cat = df_assistance[cat]

# %%
df_cat
# Out:
#                     ethnicity  gender                       race  \
# 46     Non-Hispanic or Latino  Female  Black or African American
# 51     Non-Hispanic or Latino  Female  Black or African American
# 565    Non-Hispanic or Latino  Female  Black or African American
# 630    Non-Hispanic or Latino  Female  Black or African American
# 636    Non-Hispanic or Latino  Female  Black or African American
# ...                       ...     ...                        ...
# 34947        Refuse to Answer  Female  Black or African American
# 34956  Non-Hispanic or Latino  Female  Black or African American
# 34958                  unkown  unkown                     unkown
# 34959  Non-Hispanic or Latino  Female  Black or African American
# 34962  Non-Hispanic or Latino  Female  Black or African American
#
#                   relation to hh  in atl out of county
# 46                          Self  unkown        unkown
# 51                          Self   False         False
# 565                         Self  unkown        unkown
# 630                         Self   False         False
# 636                         Self   False         False
# ...                          ...     ...           ...
# 34947                       Self  unkown        unkown
# 34956                       Self  unkown        unkown
# 34958                    unknown  unkown        unkown
# 34959                       Self  unkown        unkown
# 34962  Head of household's child  unkown        unkown
#
# [3940 rows x 6 columns]

# %%
df_cat_encoded = pd.get_dummies(df_cat)
df_cat_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3940 entries, 46 to 34962
# Data columns (total 30 columns):
#  #   Column                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                          --------------  -----
#  0   ethnicity_Hispanic or Latino                                                                    3940 non-null   uint8
#  1   ethnicity_Non-Hispanic or Latino                                                                3940 non-null   uint8
#  2   ethnicity_Refuse to Answer                                                                      3940 non-null   uint8
#  3   ethnicity_unkown                                                                                3940 non-null   uint8
#  4   gender_Female                                                                                   3940 non-null   uint8
#  5   gender_Gender Non-Conforming                                                                    3940 non-null   uint8
#  6   gender_Male                                                                                     3940 non-null   uint8
#  7   gender_Trans Female (Male to Female)                                                            3940 non-null   uint8
#  8   gender_Trans Male (Female to Male)                                                              3940 non-null   uint8
#  9   gender_unkown                                                                                   3940 non-null   uint8
#  10  race_American Indian or Alaska Native                                                           3940 non-null   uint8
#  11  race_Asian                                                                                      3940 non-null   uint8
#  12  race_Black or African American                                                                  3940 non-null   uint8
#  13  race_Multi-Racial                                                                               3940 non-null   uint8
#  14  race_Native Hawaiian or Other Pacific Islander                                                  3940 non-null   uint8
#  15  race_Refuse to Answer                                                                           3940 non-null   uint8
#  16  race_White                                                                                      3940 non-null   uint8
#  17  race_unkown                                                                                     3940 non-null   uint8
#  18  relation to hh_Head of household's child                                                        3940 non-null   uint8
#  19  relation to hh_Head of household's other relation member (other relation to head of household)  3940 non-null   uint8
#  20  relation to hh_Head of household's spouse or partner                                            3940 non-null   uint8
#  21  relation to hh_Other: non-relation member                                                       3940 non-null   uint8
#  22  relation to hh_Self                                                                             3940 non-null   uint8
#  23  relation to hh_unknown                                                                          3940 non-null   uint8
#  24  in atl_False                                                                                    3940 non-null   uint8
#  25  in atl_True                                                                                     3940 non-null   uint8
#  26  in atl_unkown                                                                                   3940 non-null   uint8
#  27  out of county_False                                                                             3940 non-null   uint8
#  28  out of county_True                                                                              3940 non-null   uint8
#  29  out of county_unkown                                                                            3940 non-null   uint8
# dtypes: uint8(30)
# memory usage: 146.2 KB

# %%
df_cat_encoded = df_cat_encoded.drop(['ethnicity_Non-Hispanic or Latino', 'gender_Male', 'race_Black or African American', 'relation to hh_Self', 'in atl_False', 'out of county_False'], axis=1, inplace=True)

# %%
df_rejoined = df_scaled#pd.concat([df_scaled, df_cat_encoded], axis=1)
y = df_rejoined.pop(target)
calculate_percent_missing(df_rejoined)
# Out:
#                       percent_missing
# age                               0.0
# income per hh mem                 0.0
# assistance requested              0.0

# %%
y
# Out:
# 46        5672.17
# 51        4357.91
# 565       9281.00
# 630       8478.65
# 636       1509.00
#            ...
# 34947    14763.72
# 34956     7659.01
# 34958     6132.89
# 34959     2656.99
# 34962     5268.50
# Name: total assistance approved, Length: 3940, dtype: float64

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
X_train, X_test, y_train, y_test = train_test_split(df_rejoined, y, test_size=TEST_FRACTION, random_state = RAND_STATE)

# %%
y_test
# Out:
# 12650     4697.98
# 15452     3299.84
# 29959     5467.00
# 22242     4045.07
# 22107    11571.00
#            ...
# 2542      7800.00
# 6666      7411.24
# 12920     8250.00
# 19908     4263.48
# 17389     3684.29
# Name: total assistance approved, Length: 985, dtype: float64

# %%
reg = LinearRegression().fit(X_train, y_train)

# %%
y_pred = reg.predict(X_test)

# %%
y_test
# Out:
# 12650     4697.98
# 15452     3299.84
# 29959     5467.00
# 22242     4045.07
# 22107    11571.00
#            ...
# 2542      7800.00
# 6666      7411.24
# 12920     8250.00
# 19908     4263.48
# 17389     3684.29
# Name: total assistance approved, Length: 985, dtype: float64

# %%
np.abs(y_pred - y_test).mean()
# Out:
# 2810.5142379903464

# %%
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 4421.3145157778845
